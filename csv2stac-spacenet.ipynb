# %% [markdown]
# # Making STAC items, collections, catalogs from a csv or dataframe
#
# Thanks @axellblanc for several early iterations of this

# %%
import pandas as pd
import geopandas as gpd
from satstac import Catalog, Collection, Item
from shapely.geometry import box

# %%
df = pd.read_csv('data/data_spacenet_andmore.csv')
df.head()
# Out:
#   collection  prefix                id              datetime  \
# 0   zanzibar  znz001  znz001_buildings  2019-04-23T00:00:00Z
# 1   zanzibar  znz029  znz029_buildings  2019-04-23T00:00:00Z
# 2   zanzibar  znz022  znz022_buildings  2019-04-23T00:00:00Z
# 3   zanzibar  znz023  znz023_buildings  2019-04-23T00:00:00Z
# 4   zanzibar  znz028  znz028_buildings  2019-04-23T00:00:00Z
#
#            td:title         td:description       td:type td:classes  \
# 0  znz001 buildings  here is a description  segmentation  buildings
# 1  znz029 buildings  here is a description  segmentation  buildings
# 2  znz022 buildings  here is a description  segmentation  buildings
# 3  znz023 buildings  here is a description  segmentation  buildings
# 4  znz028 buildings  here is a description  segmentation  buildings
#
#   asset:raster:title                                  asset:raster:href  ...  \
# 0         znz001_cog  https://oin-hotosm.s3.amazonaws.com/5afeda152b...  ...
# 1         znz029_cog  https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...  ...
# 2         znz022_cog  https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...  ...
# 3         znz023_cog  https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...  ...
# 4         znz028_cog  https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...  ...
#
#   asset:vector:license asset:thumbnail:title  \
# 0                  NaN                   NaN
# 1                  NaN      znz029_thumbnail
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
#                                 asset:thumbnail:href asset:thumbnail:type  \
# 0                                                NaN                  NaN
# 1  https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...            image/png
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   asset:chips:title                                   asset:chips:href  \
# 0               NaN                                                NaN
# 1      znz029_chips  https://www.dropbox.com/sh/9ogls4r13zqfccl/AAD...
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
#
#       asset:chips:type asset:output_rst:title  \
# 0                  NaN                    NaN
# 1  application/dropbox    model raster output
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                                asset:output_rst:href  \
# 0                                                NaN
# 1  https://www.dropbox.com/s/o8je994h9uvibpu/znz0...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                           asset:output_rst:type
# 0                                           NaN
# 1  image/vnd.stac.geotiff; cloud-optimized=true
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 24 columns]

# %%
df.T
# Out:
#                                                                        0   \
# collection                                                       zanzibar
# prefix                                                             znz001
# id                                                       znz001_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz001 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz001_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5afeda152b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz001_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAA...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        1   \
# collection                                                       zanzibar
# prefix                                                             znz029
# id                                                       znz029_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz029 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz029_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz029_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                    znz029_thumbnail
# asset:thumbnail:href    https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:thumbnail:type                                            image/png
# asset:chips:title                                            znz029_chips
# asset:chips:href        https://www.dropbox.com/sh/9ogls4r13zqfccl/AAD...
# asset:chips:type                                      application/dropbox
# asset:output_rst:title                                model raster output
# asset:output_rst:href   https://www.dropbox.com/s/o8je994h9uvibpu/znz0...
# asset:output_rst:type        image/vnd.stac.geotiff; cloud-optimized=true
#
#                                                                        2   \
# collection                                                       zanzibar
# prefix                                                             znz022
# id                                                       znz022_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz022 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz022_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz022_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        3   \
# collection                                                       zanzibar
# prefix                                                             znz023
# id                                                       znz023_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz023 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz023_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz023_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAA...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        4   \
# collection                                                       zanzibar
# prefix                                                             znz028
# id                                                       znz028_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz028 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz028_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz028_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAA...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        5   \
# collection                                                       zanzibar
# prefix                                                             znz035
# id                                                       znz035_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz035 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz035_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz035_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        6   \
# collection                                                       zanzibar
# prefix                                                             znz036
# id                                                       znz036_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz036 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz036_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz036_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAB...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        7   \
# collection                                                       zanzibar
# prefix                                                             znz042
# id                                                       znz042_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz042 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz042_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae318220b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz042_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAC...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        8   \
# collection                                                       zanzibar
# prefix                                                             znz043
# id                                                       znz043_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz043 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz043_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae318220b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz043_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        9   \
# collection                                                       zanzibar
# prefix                                                             znz049
# id                                                       znz049_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz049 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz049_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae318220b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz049_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                         ...  \
# collection              ...
# prefix                  ...
# id                      ...
# datetime                ...
# td:title                ...
# td:description          ...
# td:type                 ...
# td:classes              ...
# asset:raster:title      ...
# asset:raster:href       ...
# asset:raster:type       ...
# asset:vector:title      ...
# asset:vector:href       ...
# asset:vector:type       ...
# asset:vector:license    ...
# asset:thumbnail:title   ...
# asset:thumbnail:href    ...
# asset:thumbnail:type    ...
# asset:chips:title       ...
# asset:chips:href        ...
# asset:chips:type        ...
# asset:output_rst:title  ...
# asset:output_rst:href   ...
# asset:output_rst:type   ...
#
#                                                                        13  \
# collection                                                          accra
# prefix                                                               acc1
# id                                                      accra_1_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                          accra 1 building labels
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                            accra_1_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b694a0f4b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                               accra_1_buildings_vector
# asset:vector:href       https://s3.amazonaws.com/open-ml-challenge-sta...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        14  \
# collection                                                          accra
# prefix                                                               acc1
# id                                                         accra_1_drains
# datetime                                             2019-04-23T00:00:00Z
# td:title                                             accra 1 drain labels
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                         drains
# asset:raster:title                                            accra_1_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b694a0f4b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                  accra_1_drains_vector
# asset:vector:href       https://s3.amazonaws.com/open-ml-challenge-sta...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        15  \
# collection                                                       spacenet
# prefix                                                        khartoum805
# id                                                  khartoum805_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                        khartoum805_cog
# asset:raster:href       https://www.dropbox.com/s/rxsoa5w4r6anljc/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                           khartoum805_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/iiu1k2xi451d0gm/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        16  \
# collection                                                       spacenet
# prefix                                                          vegas2636
# id                                                    vegas2636_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                          vegas2636_cog
# asset:raster:href       https://www.dropbox.com/s/m8boillyu3ad4u0/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                             vegas2636_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/844lb2j58qqweza/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        17  \
# collection                                                       spacenet
# prefix                                                          paris1648
# id                                                    paris1648_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                          paris1648_cog
# asset:raster:href       https://www.dropbox.com/s/4t0x19sk8l4ocuj/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                             paris1648_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/8ryqu8u2q0d8lx0/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        18  \
# collection                                                       spacenet
# prefix                                                       shanghai1648
# id                                                 shanghai1648_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                       shanghai1648_cog
# asset:raster:href       https://www.dropbox.com/s/uqsi835ict7ydk6/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                          shanghai1648_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/tqtoqo5lzv7ikq3/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        19  \
# collection                                                       monrovia
# prefix                                                               mon2
# id                                                         mon2_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   mon2_buildings
# td:description                                 monrovia 2 building labels
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                               mon2_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b83a514c8...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                  mon2_buildings_vector
# asset:vector:href            data/monrovia_2/monrovia_2_buildings.geojson
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        20  \
# collection                                                       monrovia
# prefix                                                               mon2
# id                                                            mon2_drains
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                      mon2_drains
# td:description                                    monrovia 2 drain labels
# td:type                                                      segmentation
# td:classes                                                         drains
# asset:raster:title                                               mon2_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b83a514c8...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                     mon2_drains_vector
# asset:vector:href               data/monrovia_2/monrovia_2_drains.geojson
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        21  \
# collection                                                       monrovia
# prefix                                                               mon2
# id                                                             mon2_roads
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                       mon2_roads
# td:description                                    monrovia 2 roads labels
# td:type                                                      segmentation
# td:classes                                                          roads
# asset:raster:title                                               mon2_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b83a514c8...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                      mon2_roads_vector
# asset:vector:href                data/monrovia_2/monrovia_2_roads.geojson
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        22
# collection                                                    dg_opendata
# prefix                                                     beira_20190519
# id                                                         beira_20190519
# datetime                                             2019-06-03T00:00:00Z
# td:title                                                   beira_20190519
# td:description                                     beira buildings sample
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                     beira_20190519_cog
# asset:raster:href       https://opendata.digitalglobe.com/cyclone_idai...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                        beira_20190519_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/u646ervp7gc4oo0/beir...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                             ODbL 1.0
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
# [24 rows x 23 columns]

# %%
df.iloc[-1]['asset:raster:href']
# Out:
# 'https://opendata.digitalglobe.com/cyclone_idai/pre-event/2018-05-19/104001003CC14D00/0023320.tif'

# %%
df.T
# Out:
#                                                                        0   \
# collection                                                       zanzibar
# prefix                                                             znz001
# id                                                       znz001_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz001 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz001_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5afeda152b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz001_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAA...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        1   \
# collection                                                       zanzibar
# prefix                                                             znz029
# id                                                       znz029_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz029 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz029_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz029_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                    znz029_thumbnail
# asset:thumbnail:href    https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:thumbnail:type                                            image/png
# asset:chips:title                                            znz029_chips
# asset:chips:href        https://www.dropbox.com/sh/9ogls4r13zqfccl/AAD...
# asset:chips:type                                      application/dropbox
# asset:output_rst:title                                model raster output
# asset:output_rst:href   https://www.dropbox.com/s/o8je994h9uvibpu/znz0...
# asset:output_rst:type        image/vnd.stac.geotiff; cloud-optimized=true
#
#                                                                        2   \
# collection                                                       zanzibar
# prefix                                                             znz022
# id                                                       znz022_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz022 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz022_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz022_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        3   \
# collection                                                       zanzibar
# prefix                                                             znz023
# id                                                       znz023_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz023 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz023_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz023_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAA...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        4   \
# collection                                                       zanzibar
# prefix                                                             znz028
# id                                                       znz028_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz028 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz028_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz028_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAA...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        5   \
# collection                                                       zanzibar
# prefix                                                             znz035
# id                                                       znz035_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz035 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz035_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz035_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        6   \
# collection                                                       zanzibar
# prefix                                                             znz036
# id                                                       znz036_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz036 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz036_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae242fd0b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz036_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAB...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        7   \
# collection                                                       zanzibar
# prefix                                                             znz042
# id                                                       znz042_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz042 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz042_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae318220b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz042_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAC...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        8   \
# collection                                                       zanzibar
# prefix                                                             znz043
# id                                                       znz043_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz043 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz043_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae318220b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz043_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        9   \
# collection                                                       zanzibar
# prefix                                                             znz049
# id                                                       znz049_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                 znz049 buildings
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                             znz049_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5ae318220b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                znz049_buildings_vector
# asset:vector:href       https://www.dropbox.com/sh/ct3s1x2a846x3yl/AAD...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                         ...  \
# collection              ...
# prefix                  ...
# id                      ...
# datetime                ...
# td:title                ...
# td:description          ...
# td:type                 ...
# td:classes              ...
# asset:raster:title      ...
# asset:raster:href       ...
# asset:raster:type       ...
# asset:vector:title      ...
# asset:vector:href       ...
# asset:vector:type       ...
# asset:vector:license    ...
# asset:thumbnail:title   ...
# asset:thumbnail:href    ...
# asset:thumbnail:type    ...
# asset:chips:title       ...
# asset:chips:href        ...
# asset:chips:type        ...
# asset:output_rst:title  ...
# asset:output_rst:href   ...
# asset:output_rst:type   ...
#
#                                                                        13  \
# collection                                                          accra
# prefix                                                               acc1
# id                                                      accra_1_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                          accra 1 building labels
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                            accra_1_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b694a0f4b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                               accra_1_buildings_vector
# asset:vector:href       https://s3.amazonaws.com/open-ml-challenge-sta...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        14  \
# collection                                                          accra
# prefix                                                               acc1
# id                                                         accra_1_drains
# datetime                                             2019-04-23T00:00:00Z
# td:title                                             accra 1 drain labels
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                         drains
# asset:raster:title                                            accra_1_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b694a0f4b...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                  accra_1_drains_vector
# asset:vector:href       https://s3.amazonaws.com/open-ml-challenge-sta...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        15  \
# collection                                                       spacenet
# prefix                                                        khartoum805
# id                                                  khartoum805_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                        khartoum805_cog
# asset:raster:href       https://www.dropbox.com/s/rxsoa5w4r6anljc/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                           khartoum805_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/iiu1k2xi451d0gm/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        16  \
# collection                                                       spacenet
# prefix                                                          vegas2636
# id                                                    vegas2636_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                          vegas2636_cog
# asset:raster:href       https://www.dropbox.com/s/m8boillyu3ad4u0/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                             vegas2636_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/844lb2j58qqweza/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        17  \
# collection                                                       spacenet
# prefix                                                          paris1648
# id                                                    paris1648_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                          paris1648_cog
# asset:raster:href       https://www.dropbox.com/s/4t0x19sk8l4ocuj/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                             paris1648_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/8ryqu8u2q0d8lx0/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        18  \
# collection                                                       spacenet
# prefix                                                       shanghai1648
# id                                                 shanghai1648_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   RGB PanSharpen
# td:description                                      here is a description
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                       shanghai1648_cog
# asset:raster:href       https://www.dropbox.com/s/uqsi835ict7ydk6/RGB-...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                          shanghai1648_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/tqtoqo5lzv7ikq3/buil...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        19  \
# collection                                                       monrovia
# prefix                                                               mon2
# id                                                         mon2_buildings
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                   mon2_buildings
# td:description                                 monrovia 2 building labels
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                               mon2_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b83a514c8...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                  mon2_buildings_vector
# asset:vector:href            data/monrovia_2/monrovia_2_buildings.geojson
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        20  \
# collection                                                       monrovia
# prefix                                                               mon2
# id                                                            mon2_drains
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                      mon2_drains
# td:description                                    monrovia 2 drain labels
# td:type                                                      segmentation
# td:classes                                                         drains
# asset:raster:title                                               mon2_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b83a514c8...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                     mon2_drains_vector
# asset:vector:href               data/monrovia_2/monrovia_2_drains.geojson
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        21  \
# collection                                                       monrovia
# prefix                                                               mon2
# id                                                             mon2_roads
# datetime                                             2019-04-23T00:00:00Z
# td:title                                                       mon2_roads
# td:description                                    monrovia 2 roads labels
# td:type                                                      segmentation
# td:classes                                                          roads
# asset:raster:title                                               mon2_cog
# asset:raster:href       https://oin-hotosm.s3.amazonaws.com/5b83a514c8...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                                      mon2_roads_vector
# asset:vector:href                data/monrovia_2/monrovia_2_roads.geojson
# asset:vector:type                                    application/geo+json
# asset:vector:license                                                  NaN
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
#                                                                        22
# collection                                                    dg_opendata
# prefix                                                     beira_20190519
# id                                                         beira_20190519
# datetime                                             2019-06-03T00:00:00Z
# td:title                                                   beira_20190519
# td:description                                     beira buildings sample
# td:type                                                      segmentation
# td:classes                                                      buildings
# asset:raster:title                                     beira_20190519_cog
# asset:raster:href       https://opendata.digitalglobe.com/cyclone_idai...
# asset:raster:type            image/vnd.stac.geotiff; cloud-optimized=true
# asset:vector:title                        beira_20190519_buildings_vector
# asset:vector:href       https://www.dropbox.com/s/u646ervp7gc4oo0/beir...
# asset:vector:type                                    application/geo+json
# asset:vector:license                                             ODbL 1.0
# asset:thumbnail:title                                                 NaN
# asset:thumbnail:href                                                  NaN
# asset:thumbnail:type                                                  NaN
# asset:chips:title                                                     NaN
# asset:chips:href                                                      NaN
# asset:chips:type                                                      NaN
# asset:output_rst:title                                                NaN
# asset:output_rst:href                                                 NaN
# asset:output_rst:type                                                 NaN
#
# [24 rows x 23 columns]

# %%
def get_bbox(geojson_link):
    gdf = gpd.read_file(geojson_link)
    gdf = gdf[gdf['geometry'].isna() != True]
    return list(gdf['geometry'].total_bounds)

# %%
def get_geometry(address):
    data = gpd.read_file(address); 
    geom = []
    for f in data['geometry']:
        if(f is not None):
            #We now have to know wether it is a multipolygon or polygon or multiLineString or LineString,
            #in order to get the complete geometry and not only the first polygon/line
            if('Polygon' in str(type(data['geometry'][0])) or 'Polygon' in str(type(data['geometry'][1]))):   
                geom_type = 'Polygon'
                if(f.type == 'MultiPolygon'):   
                    polygons = list(f)
                    for po in polygons:
                        x, y = po.exterior.coords.xy
                        geom.append([[[x[i],y[i]] for i in range(len(x))]])
                else:
                    x, y = f.exterior.coords.xy
                    geom.append([[[x[i],y[i]] for i in range(len(x))]])
            if('line' in str(type(data['geometry'][0])) or 'line' in str(type(data['geometry'][1]))):
                geom_type = 'LineString'
                if('Multi' in str(type(data['geometry'][0]))):   
                    lines = list(f)
                    for li in lines:
                        x, y = li.coords.xy
                        geom.append([[x[i],y[i]] for i in range(len(x))])
                else:
                    x, y = f.coords.xy
                    geom.append([[x[i],y[i]] for i in range(len(x))]) 
            if('point' in str(type(data['geometry'][0])) or 'point' in str(type(data['geometry'][1]))):
                geom_type = 'LineString'
                if('Multi' in str(type(data['geometry'][0]))):   
                    points = list(f)
                    for po in points:
                        x, y = li.coords.xy
                        geom.append([x[i],y[i]] for i in range(len(x)))
                else:
                    x, y = f.coords.xy
                    geom.append([x[i],y[i]] for i in range(len(x))) 
    geometry_item = {
        "type": "Multi" + geom_type,
        "coordinates": geom
        } 
    return geometry_item

# %%
properties_k = [o for o in list(df.columns) if 'datetime' in o or 'td:' in o]
assets_k = [o for o in list(df.columns) if 'asset:' in o]

# %%
properties_k, assets_k
# Out:
# (['datetime', 'td:title', 'td:description', 'td:type', 'td:classes'],
#  ['asset:raster:title',
#   'asset:raster:href',
#   'asset:raster:type',
#   'asset:vector:title',
#   'asset:vector:href',
#   'asset:vector:type',
#   'asset:vector:license',
#   'asset:thumbnail:title',
#   'asset:thumbnail:href',
#   'asset:thumbnail:type',
#   'asset:chips:title',
#   'asset:chips:href',
#   'asset:chips:type',
#   'asset:output_rst:title',
#   'asset:output_rst:href',
#   'asset:output_rst:type'])

# %%
df.collection.unique()
# Out:
# array(['zanzibar', 'accra', 'spacenet', 'monrovia', 'dg_opendata'],
#       dtype=object)

# %%
collections_df = {o:df[df.collection==o] for o in df.collection.unique()}

# %%
collections_df['spacenet']
# Out:
#    collection        prefix                      id              datetime  \
# 15   spacenet   khartoum805   khartoum805_buildings  2019-04-23T00:00:00Z
# 16   spacenet     vegas2636     vegas2636_buildings  2019-04-23T00:00:00Z
# 17   spacenet     paris1648     paris1648_buildings  2019-04-23T00:00:00Z
# 18   spacenet  shanghai1648  shanghai1648_buildings  2019-04-23T00:00:00Z
#
#           td:title         td:description       td:type td:classes  \
# 15  RGB PanSharpen  here is a description  segmentation  buildings
# 16  RGB PanSharpen  here is a description  segmentation  buildings
# 17  RGB PanSharpen  here is a description  segmentation  buildings
# 18  RGB PanSharpen  here is a description  segmentation  buildings
#
#    asset:raster:title                                  asset:raster:href  ...  \
# 15    khartoum805_cog  https://www.dropbox.com/s/rxsoa5w4r6anljc/RGB-...  ...
# 16      vegas2636_cog  https://www.dropbox.com/s/m8boillyu3ad4u0/RGB-...  ...
# 17      paris1648_cog  https://www.dropbox.com/s/4t0x19sk8l4ocuj/RGB-...  ...
# 18   shanghai1648_cog  https://www.dropbox.com/s/uqsi835ict7ydk6/RGB-...  ...
#
#    asset:vector:license asset:thumbnail:title asset:thumbnail:href  \
# 15                  NaN                   NaN                  NaN
# 16                  NaN                   NaN                  NaN
# 17                  NaN                   NaN                  NaN
# 18                  NaN                   NaN                  NaN
#
#    asset:thumbnail:type asset:chips:title asset:chips:href asset:chips:type  \
# 15                  NaN               NaN              NaN              NaN
# 16                  NaN               NaN              NaN              NaN
# 17                  NaN               NaN              NaN              NaN
# 18                  NaN               NaN              NaN              NaN
#
#    asset:output_rst:title asset:output_rst:href asset:output_rst:type
# 15                    NaN                   NaN                   NaN
# 16                    NaN                   NaN                   NaN
# 17                    NaN                   NaN                   NaN
# 18                    NaN                   NaN                   NaN
#
# [4 rows x 24 columns]

# %%
def make_items(df, convert_geom=False):
    items=[]

    for idx in range(len(df)):
        one_item = {}
        one_item['id'] = df.iloc[idx]['id']
        one_item['type'] = 'Feature'
        one_item['bbox'] = get_bbox(df.iloc[idx]['asset:vector:href'])
        
        # converting geometry of item.json to individual buildings if True, otherwise Polygon(bbox)
        if convert_geom: one_item['geometry'] = get_geometry(df.iloc[idx]['asset:vector:href'])
        else: 
            one_item['geometry'] = {
            "type": "Polygon",
            "coordinates": [[[x,y] for x,y in box(*one_item['bbox']).exterior.coords]]
        }
        
        # make dicts for each asset type
        one_item['assets'] = {}
        for a in assets_k:
            _, b, c = a.split(':')
            if not pd.isnull(df.iloc[idx][a]): one_item['assets'][b] = {}
        # update each asset
        for a in assets_k:
            _, b, c = a.split(':')
            if not pd.isnull(df.iloc[idx][a]): one_item['assets'][b].update({
                c : df.iloc[idx][a]
            })

        item_json = {}
        for p in properties_k: item_json[p] = df.iloc[idx][p]
        one_item['properties'] = item_json
        
        items.append(one_item)
    return items

# %%
test_items = make_items(collections_df['spacenet'], True)

# %%
test_items[0]
# Out:
# {'id': 'khartoum805_buildings',
#  'type': 'Feature',
#  'bbox': [32.550773400023665,
#   15.629641199956897,
#   32.55252840002398,
#   15.631396199957209],
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[32.5509926770145, 15.629641199956897],
#      [32.55099261484361, 15.629649577616853],
#      [32.55112571552431, 15.62965049289118],
#      [32.55112578448747, 15.629641199956897],
#      [32.5509926770145, 15.629641199956897]]],
#    [[[32.551256676418035, 15.629654602109115],
#      [32.551256354234056, 15.629641199956897],
#      [32.55117788748293, 15.629641199956897],
#      [32.551178251697095, 15.629656350473141],
#      [32.551256676418035, 15.629654602109115]]],
#    [[[32.55215878997613, 15.629641199956897],
#      [32.55215847267387, 15.629649144202565],
#      [32.55214339355356, 15.629648585348866],
#      [32.55214247637358, 15.629671545927788],
#      [32.552157555494, 15.629672104781308],
#      [32.55222298518602, 15.629674527922031],
#      [32.5522219278689, 15.629701005122712],
#      [32.55215649817685, 15.629698581982256],
#      [32.55215525940009, 15.629729594889643],
#      [32.552119331280295, 15.629728263503486],
#      [32.552115493677434, 15.629824361183852],
#      [32.55215142179721, 15.629825692569398],
#      [32.55215103821659, 15.629835291694157],
#      [32.55234579386848, 15.629842504879042],
#      [32.55240282610927, 15.629844617447697],
#      [32.55240531713759, 15.629782240433228],
#      [32.552473484894534, 15.629784764789148],
#      [32.55247099386628, 15.629847142667801],
#      [32.55252840002398, 15.629849269020612],
#      [32.55252840002398, 15.629641199956897],
#      [32.55215878997613, 15.629641199956897]]],
#    [[[32.55164878654796, 15.629828010166365],
#      [32.551623830451085, 15.629827437471631],
#      [32.55162299591618, 15.629861207425604],
#      [32.55164795201304, 15.629861779255151],
#      [32.55164878654796, 15.629828010166365]]],
#    [[[32.550843527744156, 15.62974080137127],
#      [32.550773400023665, 15.629739432872848],
#      [32.550773400023665, 15.62987543075829],
#      [32.5508406675083, 15.62987674284833],
#      [32.550843527744156, 15.62974080137127]]],
#    [[[32.55174473021355, 15.629853035713188],
#      [32.55168840045539, 15.629853035713188],
#      [32.55168840045539, 15.629895608895234],
#      [32.55174473021355, 15.629895608895234],
#      [32.55174473021355, 15.629853035713188]]],
#    [[[32.55199008167722, 15.629926280059347],
#      [32.55198997118448, 15.629911265429106],
#      [32.55198987506473, 15.62989825868881],
#      [32.55105326549834, 15.631024414401223],
#      [32.55105276962834, 15.631045853127858],
#      [32.550935454143804, 15.631043334843246],
#      [32.550927285162786, 15.631396199957209],
#      [32.551289395549304, 15.631396199957209]]],
#    [[[32.552009835113466, 15.629641199956897],
#      [32.55200876663512, 15.629659715706259],
#      [32.55203479801544, 15.62966110851493],
#      [32.55203594686785, 15.629641199956897],
#      [32.552009835113466, 15.629641199956897]]],
#    [[[32.55198191509301, 15.62972004766577],
#      [32.55198327244735, 15.62965469121425],
#      [32.55193021974334, 15.629653669532953],
#      [32.55192909864587, 15.629707620529393],
#      [32.55186129201159, 15.629706314230981],
#      [32.55186040447605, 15.629749076899968],
#      [32.55192821111033, 15.629750383198111],
#      [32.5519280781597, 15.629756789249413],
#      [32.55201103038967, 15.629758387085621],
#      [32.552011814618936, 15.629720623821216],
#      [32.55198191509301, 15.62972004766577]]],
#    [[[32.551841998894226, 15.629802966449313],
#      [32.55184612305967, 15.629691769332865],
#      [32.55189054654713, 15.629693297096594],
#      [32.5518917727475, 15.629660214868121],
#      [32.55191042446771, 15.629660856771254],
#      [32.55191115316035, 15.629641199956897],
#      [32.55180596292586, 15.629641199956897],
#      [32.55180536829189, 15.629657243254877],
#      [32.551735172138926, 15.62965482876492],
#      [32.55173567757685, 15.629641199956897],
#      [32.55161215218407, 15.629641199956897],
#      [32.55160863544801, 15.629736025164403],
#      [32.55164668359191, 15.629737334057841],
#      [32.55164489684279, 15.629785511368611],
#      [32.551706360472814, 15.62978762480295],
#      [32.551707695369345, 15.629751636725269],
#      [32.55174194543618, 15.6297528149889],
#      [32.55174433944644, 15.629688268279883],
#      [32.55176968720878, 15.62968914029901],
#      [32.55176556394163, 15.62980033741677],
#      [32.551841998894226, 15.629802966449313]]]]},
#  'assets': {'raster': {'title': 'khartoum805_cog',
#    'href': 'https://www.dropbox.com/s/rxsoa5w4r6anljc/RGB-PanSharpen_AOI_5_Khartoum_img805_cog.tif?dl=1',
#    'type': 'image/vnd.stac.geotiff; cloud-optimized=true'},
#   'vector': {'title': 'khartoum805_buildings_vector',
#    'href': 'https://www.dropbox.com/s/iiu1k2xi451d0gm/buildings_AOI_5_Khartoum_img805.geojson?dl=1',
#    'type': 'application/geo+json'}},
#  'properties': {'datetime': '2019-04-23T00:00:00Z',
#   'td:title': 'RGB PanSharpen',
#   'td:description': 'here is a description',
#   'td:type': 'segmentation',
#   'td:classes': 'buildings'}}

# %%
def get_totalbounds(items):
    poly_list = []
    for item in items: poly_list.append(box(*item['bbox']))
    bbox_gpd = gpd.GeoSeries(poly_list)
    return list(bbox_gpd.total_bounds)

# %%
get_totalbounds(test_items)
# Out:
# [-115.23556259985658,
#  15.629641199956897,
#  121.66738919996575,
#  49.00558590002751]

# %% [markdown]
# # Catalog

# %%
stac_version = '0.7'

# %%
cat_json = {
    "id": "openml_data_demo",
    "title": "stac4ml demo",
    "description": "Sample ML training data in the STAC format",
    "stac_version": stac_version
}

mycat = Catalog(cat_json, root='https://my.cat')
mycat.save_as('catalog.json')
# Out:
# openml_data_demo

# %% [markdown]
# # Collections

# %%
for coll_name in df.collection.unique():
    print(coll_name)
    items = make_items(collections_df[coll_name], True)
    
    coll_json = {
    "stac_version": stac_version,
    "id": f'{coll_name}-collection',
    "title": f'{coll_name} AoI' ,
    "description": 'this description',
    "extent": {
        "spatial": get_totalbounds(items),
        "temporal": [
          "2019-05-23T00:00:00Z", None
        ]
      },
    
    "collection version": "1.0",
    "keywords": [
        "challenge"
    ],
    "license": "CC-BY-4.0",
    }

    if coll_name=='dg_opendata': coll_json['license'] = "CC-BY-NC-4.0"
    if coll_name=='spacenet': coll_json['license'] = "CC-BY-SA-04.0"
    
    coll = Collection(coll_json)
    mycat.add_catalog(coll)

    for i in items: coll.add_item(Item(i))
# Out:
# zanzibar

# %% [markdown]
# ### Define individual collections

# %%
coll_name = 'spacenet'
items = make_items(collections_df[coll_name], True)

coll_json = {
    "stac_version": stac_version,
    "id": f'{coll_name}-collection',
    "title": f'{coll_name} AoI' ,
    "description": 'this description',
    "extent": {
        "spatial": get_totalbounds(items),
        "temporal": [
          "2019-05-23T00:00:00Z", None
        ]
      },
    
    "collection version": "1.0",
    "keywords": [
        "challenge",
        "spacenet",
        "khartoum"
    ],
    "license": "CC-BY-4.0",
    }

coll = Collection(coll_json)
mycat.add_catalog(coll)

for i in items: coll.add_item(Item(i))

# %%
coll_name = 'zanzibar'
items = make_items(collections_df[coll_name], True)

coll_json = {
    "stac_version": stac_version,
    "id": f'{coll_name}-collection',
    "title": f'{coll_name} AoI' ,
    "description": 'this description',
    "extent": {
        "spatial": get_totalbounds(items),
        "temporal": [
          "2019-05-23T00:00:00Z", None
        ]
      },
    
    "collection version": "1.0",
    "keywords": [
        "challenge",
        "zanzibar"
    ],
    "license": "CC-BY-4.0",
    }

coll = Collection(coll_json)
mycat.add_catalog(coll)

for i in items: coll.add_item(Item(i))

# %%
coll.data
# Out:
# {'stac_version': '0.7',
#  'id': 'zanzibar-collection',
#  'title': 'zanzibar AoI',
#  'description': 'this description',
#  'extent': {'spatial': [39.28919876472999,
#    -5.987213391948287,
#    39.36953783435138,
#    -5.722212794937691],
#   'temporal': ['2019-05-23T00:00:00Z', None]},
#  'collection version': '1.0',
#  'keywords': ['challenge', 'zanzibar'],
#  'license': 'CC-BY-4.0',
#  'links': [{'rel': 'self',
#    'href': 'https://my.cat/zanzibar-collection/catalog.json'},
#   {'rel': 'root', 'href': '../catalog.json'},
#   {'rel': 'parent', 'href': '../catalog.json'}]}

# %%
coll_name = 'accra'

items = make_items(collections_df[coll_name])

coll_json = {
    "stac_version": stac_version,
    "id": f'{coll_name}-collection',
    "title": f'{coll_name} AoI' ,
    "description": 'this description',
    "extent": {
        "spatial": get_totalbounds(items),
        "temporal": [
          "2019-05-23T00:00:00Z", None
        ]
      },
    
    "collection version": "1.0",
    "keywords": [
        "challenge",
        "accra"
    ],
    "license": "CC-BY-4.0",
    }

coll = Collection(coll_json)
mycat.add_catalog(coll)

for i in items: coll.add_item(Item(i))

# %% [markdown]
# # Update root abs path, not needed in 0.7 anymore?

# %%
mycat.publish('https://zen-turing-2069dc.netlify.com')
